# %%
# This is the one we work on for prototype
import random
import requests
import csv 
import json
import datetime
from datetime import timedelta
import tkinter as tk
from tkinter import *
import time
from tkinter import ttk
from PIL import Image, ImageTk

class prototype():
    def __init__(self) -> None:
        pass
    
    def All(self):
        window = Tk()
        window.geometry('1200x1200')
        window.title('Daily NBA Scoreboard')

        game_select = StringVar()
        game_select.set("Select a Game")
        game_id = StringVar()
        game_id.set(" ")
        date_entry = StringVar()
        date_entry.get()
            
        menu = Menu(window)
         
        Matchups_menu = Menu(menu)
        Matchups_menu.add_command(label ="Matchups", activebackground='red', command = lambda: Matchups_page())
        menu.add_cascade(label= "Matchups", menu=Matchups_menu)
        
        Standings_menu= Menu(menu)
        Standings_menu.add_command(label = "NBA Standings", activebackground='red', command = lambda: display_NBA_standings())
        Standings_menu.add_command(label = "Eastern Conference Standings", activebackground='red', command = lambda: display_east_standings())
        Standings_menu.add_command(label = "Western Conference Standings", activebackground='red', command = lambda: display_west_standings())
        menu.add_cascade(label = 'Standings', menu= Standings_menu)

        Stats_menu= Menu(menu)
        Stats_menu.add_command(label = "PPG Leaders", activebackground='red', command = lambda: points_leaders())
        Stats_menu.add_command(label = "APG Leaders", activebackground='red', command = lambda: assists_leaders())
        Stats_menu.add_command(label = "RPG Leaders", activebackground='red', command = lambda: rebounds_leaders())
        Stats_menu.add_command(label = "BPG Leaders", activebackground='red', command = lambda: blocks_leaders())
        Stats_menu.add_command(label = "SPG Leaders", activebackground='red', command = lambda: steals_leaders())
        menu.add_cascade(label = 'Stats', menu= Stats_menu)
        
        Homepage_menu = Menu(menu)
        Homepage_menu.add_command(label = "Close Window", activebackground='red', command = lambda: exit())
        menu.add_cascade(label = 'Quit', menu = Homepage_menu)
        
        
        mainframe = Frame(window, highlightcolor="black", highlightthickness=5,borderwidth=3)
        mainframe.place(x= 600, y=400, anchor=CENTER)
        
        
        #main frames
        header = Frame(mainframe, height= 100)
        body = Frame(mainframe,height=600, width=400, pady=10, padx=10, borderwidth=4)
        bottom = Frame(mainframe, height=50, width=300, pady=10, padx=10, borderwidth=4)
        
        #sub frames for body
        body_left = Frame(body, pady=10, padx=10)
        body_right = Frame(body, pady=10, padx=10)
        
        header_logo = Frame(header,pady=10, padx=10)
        header_text = Frame(header,pady=10, padx=10)
        
        header.grid(row=0, column=0, columnspan=3)
        body.grid(row=1, column=0, columnspan=3)
        bottom.grid(row=2, column=0, columnspan=3)
        body_left.grid(row=0, column = 0)
        body_right.grid(row=0, column = 1)
        header_logo.grid(row=2,column=0)
        header_text.grid(row=0,column=0)
         
        def game_id():
            #date = datetime.date.today().strftime('%Y/%m/%d')
            date = '2024/04/07'
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/games/{date}/schedule.json?api_key={key}"
            headers = {"accept": "application/json"}
            reposnse = requests.get(url, headers=headers)
            game = reposnse.json()
            x = 0
            todays_game_dict = {}
            while IndexError is not True:
                try:
                    home_team = game['games'][x]['home']['name']
                    away_team = game['games'][x]['away']['name']
                    game_id = game['games'][x]['id']
                    home_team_alias = game['games'][x]['home']['alias']
                    away_team_alias = game['games'][x]['away']['alias']
                    todays_game_dict.update({f'{away_team} @ {home_team}':[game_id,away_team_alias, home_team_alias]})
                    x+=1     
                except:
                    if todays_game_dict == {}:
                        print('error for game)id function or no games today')
                        break
                    else:
                        break
            return todays_game_dict
        
        def current_scehudle():
            #date = datetime.date.today().strftime('%Y/%m/%d')
            date = '2024/04/07'
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/games/{date}/schedule.json?api_key={key}"
            headers = {"accept": "application/json"}
            game = requests.get(url, headers=headers).json()
            x = 0
            todays_game_dict = {}
            current_scedule_txt.delete("1.0", "end")
            while IndexError is not True:
                try:
                    home_team = game['games'][x]['home']['name']
                    away_team = game['games'][x]['away']['name']
                    time = game['games'][x]['scheduled']
                     #[
                    dt = datetime.datetime.strptime(time, '%Y-%m-%dT%H:%M:%SZ')
                    local_dt = dt - timedelta(hours=4)
                    formatted_time = local_dt.strftime('%I:%M %p')
                    todays_game_dict.update({f'{away_team} @ {home_team}':'game_id'})
                    #] I got the syntax for how to change the times to how i want from Google search
                    current_scedule_txt.insert(END, f'{away_team} @ {home_team} Scheduled for {formatted_time} Est\n')
                    current_scedule_txt.insert(END,"---------------------------------------------------------------------\n")
                    x+=1
                except:
                    if todays_game_dict == {}:
                        current_scedule_txt.insert(END,"There are no games Today. Please go into the backend and uncomment out the other date varible and comment out the other one. \n")
                        break
                    else:
                        break
                    
        def upcoming_scehudle():
            today = datetime.date.today()
            tmrw = today + timedelta(1)
            tommorow = tmrw.strftime('%Y/%m/%d')
            #tommorow = '2024/04/16'
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/games/{tommorow}/schedule.json?api_key={key}"
            headers = {"accept": "application/json"}
            game = requests.get(url, headers=headers).json()
            x = 0
            tmrw_dict = {}
            tmrw_scedule_txt.delete("1.0", "end")
            while IndexError is not True:
                try:
                    home_team = game['games'][x]['home']['name']
                    away_team = game['games'][x]['away']['name']
                    time = game['games'][x]['scheduled']
                        #[
                    dt = datetime.datetime.strptime(time, '%Y-%m-%dT%H:%M:%SZ')
                    local_dt = dt - timedelta(hours=4)
                    formatted_time = local_dt.strftime('%I:%M %p')
                    tmrw_dict.update({f'{away_team} @ {home_team}':'hello'})
                    #] I got the syntax for how to change the times to how i want from Google search  
                    tmrw_scedule_txt.insert(END, f'{away_team} @ {home_team} Scheduled for {formatted_time} Est\n')
                    tmrw_scedule_txt.insert(END,"---------------------------------------------------------------------\n")
                    x+=1
                except:
                    if tmrw_dict == {}:
                        tmrw_scedule_txt.insert(END,"There are no games Tomorrow. \n")
                        break
                    else:
                        break    
                       
        def exit():
            window.destroy()
        
        def Matchups_page():
            matchup = Tk()
            matchup.geometry('1200x1200')
            matchup.title('Matchups')     
            game_select = StringVar()
            game_select.set("Select a Game")
            date_entry = StringVar()
            date_entry.get()

            mainframe = Frame(matchup, highlightcolor="violet red", highlightthickness=5)
            mainframe.place(x=600, y=400, anchor=CENTER)
    
            #main frames
            header = Frame(mainframe, height= 400,width=400, pady=10, padx=10, borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            body = Frame(mainframe,height=600, width=400, pady=10, padx=10, borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            bottom = Frame(mainframe, height=50, width=300, pady=10, padx=10, borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            
            #sub frames for body
            
            away_logo = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            home_logo = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            away_team = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            home_team = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            clock = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            quarter = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            away_score = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            home_score = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            home_timeouts = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            away_timeouts = Frame(header,borderwidth=4,highlightcolor="violet red", highlightthickness=5)
            body_left = Frame(body, pady=10, padx=10)
            body_right = Frame(body, pady=10, padx=10)
        
            header.grid(row=0, column=0, columnspan=3)
            body.grid(row=2, column=0, columnspan=3)
            bottom.grid(row=3, column=0, columnspan=3)
            body_left.grid(row=0, column = 0)
            body_right.grid(row=0, column =1) 
            away_logo.grid(row=0, column=1)
            away_team.grid(row=0, column=0)
            away_score.grid(row=0, column=2)
            clock.grid(row=0,column=3)
            quarter.grid(row=1,column=3)
            home_score.grid(row=0,column=4)
            home_logo.grid(row=0, column=5)
            home_team.grid(row=0,column=6)
            home_timeouts.grid(row=1,column=4)
            away_timeouts.grid(row=1,column=2)
            
            awaylogostr = tk.StringVar(away_logo)
            awayteamstr = tk.StringVar(away_team)
            awayscorestr = tk.StringVar(away_score)
            gameclockstr = tk.StringVar(clock)
            gamequarterstr = tk.StringVar(quarter)
            homescorestr = tk.StringVar(home_score)
            homelogostr = tk.StringVar(home_logo)
            hometeamstr = tk.StringVar(home_team)
            hometmstr = tk.StringVar(home_timeouts)
            awaytmstr = tk.StringVar(away_timeouts)
            
            awaylogostr.get()
            awayteamstr.get()
            awayscorestr.get()
            gameclockstr.get()
            gamequarterstr.get()
            homescorestr.get()
            homelogostr.get()
            hometeamstr.get()
            hometmstr.get()
            awaytmstr.get()
            
            def Box_score_team_lead(game_id, option = None):
                id = game_id
                opt = option
                try:
                    api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
                    key = random.choice(api_list)
                    Team_leaders.delete("1.0", "end")
                    Team_leaders.insert(END, f"______________________________\n")
                    url = f"https://api.sportradar.com/nba/trial/v8/en/games/{id}/boxscore.json?api_key={key}"
                    headers = {"accept": "application/json"}
                    response = requests.get(url, headers=headers)
                    game = response.json()
                    away_team = game['away']['name']
                    home_team = game['home']['name']                
                    Team_leaders.delete("1.0", "end")
                    Home_points_name = game['home']['leaders']['points'][0]['full_name']
                    Home_points_pp = game['home']['leaders']['points'][0]['primary_position']
                    Home_points_points = game['home']['leaders']['points'][0]['statistics']['points']
                    Home_rebound_name = game['home']['leaders']['rebounds'][0]['full_name']
                    Home_rebound_pp = game['home']['leaders']['rebounds'][0]['primary_position']
                    Home_rebound_rebounds = game['home']['leaders']['points'][0]['statistics']['rebounds']
                    Home_assist_name = game['home']['leaders']['assists'][0]['full_name']
                    Home_assist_pp = game['home']['leaders']['assists'][0]['primary_position']
                    Home_assist_assits = game['home']['leaders']['assists'][0]['statistics']['assists']
                    Home_points_leader = (f'{Home_points_name} | Position: {Home_points_pp} | Total: {Home_points_points}')
                    Home_assist_leader = (f'{Home_assist_name} | Position: {Home_assist_pp} | Total: {Home_assist_assits}')
                    Home_rebound_leader = (f'{Home_rebound_name} | Position: {Home_rebound_pp} | Total: {Home_rebound_rebounds}')
                    Team_leaders.insert(END,f'{home_team}\n')
                    Team_leaders.insert(END,f'--------------\n')
                    Team_leaders.insert(END,f'Points Leader: {Home_points_leader}\n')
                    Team_leaders.insert(END,f'Assist Leader: {Home_assist_leader}\n')
                    Team_leaders.insert(END,f'Rebound Leader: {Home_rebound_leader}\n')
                    Team_leaders.insert(END,f'- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -\n')
                    #------------------------------------------------------------------------------------------
                    Away_points_name = game['away']['leaders']['points'][0]['full_name']
                    Away_points_pp = game['away']['leaders']['points'][0]['primary_position']
                    Away_points_points = game['away']['leaders']['points'][0]['statistics']['points']
                    Away_rebound_name = game['away']['leaders']['rebounds'][0]['full_name']
                    Away_rebound_pp = game['away']['leaders']['rebounds'][0]['primary_position']
                    Away_rebound_rebounds = game['away']['leaders']['points'][0]['statistics']['rebounds']
                    Away_assist_name = game['away']['leaders']['assists'][0]['full_name']
                    Away_assist_pp = game['away']['leaders']['assists'][0]['primary_position']
                    Away_assist_assits = game['away']['leaders']['assists'][0]['statistics']['assists']
                    Away_points_leader = (f'{Away_points_name} | Position: {Away_points_pp} | Total: {Away_points_points}')
                    Away_assist_leader = (f'{Away_assist_name} | Position: {Away_assist_pp} | Total: {Away_assist_assits}')
                    Away_rebound_leader = (f'{Away_rebound_name} | Position: {Away_rebound_pp} | Total: {Away_rebound_rebounds}')
                    Team_leaders.insert(END,f'{away_team}\n')
                    Team_leaders.insert(END,f'---------------\n')
                    Team_leaders.insert(END,f'Points Leader: {Away_points_leader}\n')
                    Team_leaders.insert(END,f'Assist Leader: {Away_assist_leader}\n')
                    Team_leaders.insert(END,f'Rebound Leader: {Away_rebound_leader}\n')
                except:
                    Team_leaders.insert(END,f'The Game you have selected has not begun.\n')
                    print("Error in Function Box_score_team_lead in Matchup_page Function ")
                             
            def quarter_box_score(game_id, option = None):
                id = game_id
                opt = option
                try:
                    api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
                    key = random.choice(api_list)
                    Quarter_scores.delete("1.0", "end")
                    url = f"https://api.sportradar.com/nba/trial/v8/en/games/{id}/boxscore.json?api_key={key}"
                    headers = {"accept": "application/json"}
                    game = requests.get(url, headers=headers).json()
            
                    away_team = game['away']['name']
                    home_team = game['home']['name']
                    away_scoring = game['away']['scoring']
                    home_scoring = game['home']['scoring']
                    
                    Quarter_scores.insert(END,f'{home_team}\n') 
                    Quarter_scores.insert(END,f'-----------\n')   
                    for i in home_scoring:
                        quarter = i['number']
                        points_scored = i['points']
                        home_quarter_box_score = (f'Quarter {quarter}: {points_scored} points')
                        Quarter_scores.insert(END,f'{home_quarter_box_score}\n')
                        
                    Quarter_scores.insert(END,f'- - - - - - - - - - -  \n')
                    Quarter_scores.insert(END,f'{away_team}\n')
                    Quarter_scores.insert(END,f'-----------\n')
                    for i in away_scoring:
                        quarter = i['number']
                        points_scored = i['points']
                        away_quarter_box_score= (f'Quarter {quarter}: {points_scored} points')
                        Quarter_scores.insert(END,f'{away_quarter_box_score}\n')
                except:
                    Quarter_scores.insert(END,f'The Game you have selected has not begun. \n')
                    print('Error in quarter_box_score function :in Matchup Page Function')
                       
            def data(game_id, option = None):
                id = game_id
                opt = option
                try:
                    api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
                    key = random.choice(api_list)
                    url = f"https://api.sportradar.com/nba/trial/v8/en/games/{id}/boxscore.json?api_key={key}"
                    headers = {"accept": "application/json"}
                    response = requests.get(url, headers=headers)
                    game = response.json()
                    
                    clock = game['clock']
                    quarter = game['quarter']
                    away_team = game['away']['name']
                    home_team = game['home']['name']
                    away_score = game['away']['points']
                    home_score = game['home']['points']
                    away_timeouts_remaning = game['away']['remaining_timeouts']
                    home_timeouts_remaning = game['home']['remaining_timeouts']
                    
                    awaylogostr.set('away Logo')
                    awayteamstr.set(away_team)
                    awayscorestr.set(away_score)
                    gameclockstr.set(clock)
                    gamequarterstr.set(quarter)
                    homescorestr.set(home_score)
                    homelogostr.set("Home Logo")
                    hometeamstr.set(home_team)
                    hometmstr.set(home_timeouts_remaning)
                    awaytmstr.set(away_timeouts_remaning)
                
                    matchup.update_idletasks()
                except:
                    print('Error in Data Function:in Matchup Page Function')
                      
            matchups = game_id()
            def chose_game():
                option = game_select.get()
                value = matchups[option]
                game_id = value[0]
                Logo_home = value[2]
                Logo_away = value[1]
                Box_score_team_lead(game_id,option)
                quarter_box_score(game_id,option)
                data(game_id,option)
            
            
            drop_label = Label(bottom, text="Choose a Matchup")
            drop_label.pack()
            dropdown = OptionMenu(bottom, game_select, *matchups)
            dropdown.pack()
            
            awaylogo = Label(away_logo, textvariable= awaylogostr)
            awaylogo.pack()
            awayteam = Label(away_team, textvariable= awayteamstr).pack()
            awayscore = Label(away_score,textvariable= awayscorestr).pack()
            gameclock = Label(clock,textvariable= gameclockstr).pack()
            gamequarter = Label(quarter,textvariable=gamequarterstr).pack()
            homelogo = Label(home_logo,textvariable= homelogostr)
            homelogo.pack()
            homescore = Label(home_score, textvariable= homescorestr).pack()
            hometeam = Label(home_team, textvariable= hometeamstr).pack()
            hometm = Label(home_timeouts, textvariable= hometmstr).pack()
            awaytm = Label(away_timeouts, textvariable= awaytmstr).pack()
            choose_button = Button(bottom, text="Confirm Match Selection", command=chose_game)
            choose_button.pack(pady= 20)
            
            quarter_scores_label= Label(body_left, text="Quarter Scores").pack()           
            Quarter_scores = Text(body_left, height=15,width=45)
            Quarter_scores.pack()
            
            Team_leader_label= Label(body_right, text="Team Box-Score").pack()
            Team_leaders = Text(body_right, height=15, width=70)
            Team_leaders.pack()
            close_window = Button(bottom, font = 35, text = "Close Window", command=matchup.destroy, justify='center')
            close_window.pack()
            
            matchup.mainloop()
        
        def display_NBA_standings():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={key}"
            standings = requests.get(url).json()
            confNum = 0
            divNum = 0
            teamNum = 0
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('NBA Standings')
            def sort_treeview(treeview, col, descending):
                data = [(treeview.set(item, col), item) for item in treeview.get_children('')]
                data.sort(reverse=descending)
                for index, (val, item) in enumerate(data):
                    treeview.move(item, '', index)
                treeview.heading(col, command=lambda: sort_treeview(treeview, col, not descending))
            columns=("Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for col in columns:
                treeview.heading(col, text=col, command=lambda c=col: sort_treeview(treeview, c, False))
                treeview.column(col, width=100)
            while confNum < 2:
                conference = standings["conferences"][confNum]
                while divNum < 3:
                    division = conference["divisions"][divNum]
                    while teamNum < 5:
                        team = division["teams"][teamNum]
                        team_name = team["name"]
                        if confNum == 0:
                            team_conf = "West"
                        else:
                            team_conf = "East"
                        team_w = team["wins"]
                        team_l = team["losses"]
                        team_pct = team["win_pct"]
                        team_gb = team["games_behind"]["conference"]
                        team_ppg = team["points_for"]
                        team_papg = team["points_against"]
                        team_pd = team["point_diff"]        
                        treeview.heading("#0", text="Team")
                        treeview.heading("Conference", text="Confrence")
                        treeview.heading("Wins", text="Wins")
                        treeview.heading("Losses", text="Losses")
                        treeview.heading("Win Pct", text="Win Pct")
                        treeview.heading("GB", text="GB")
                        treeview.heading("PPG", text="PPG")
                        treeview.heading("PAPG", text="PAPG")
                        treeview.heading("PD", text="PD")
                        treeview.insert('',tk.END, text=team_name, values=(team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd))
                        teamNum += 1
                    divNum += 1
                    teamNum = 0
                confNum += 1
                divNum = 0
            treeview.pack()

        def display_east_standings():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={key}"
            standings = requests.get(url).json()
            confNum = 1
            divNum = 0
            teamNum = 0
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('Eastern Conference Standings')
            def sort_treeview(treeview, col, descending):
                data = [(treeview.set(item, col), item) for item in treeview.get_children('')]
                data.sort(reverse=descending)
                for index, (val, item) in enumerate(data):
                    treeview.move(item, '', index)
                treeview.heading(col, command=lambda: sort_treeview(treeview, col, not descending))
            columns=("Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for col in columns:
                treeview.heading(col, text=col, command=lambda c=col: sort_treeview(treeview, c, False))
                treeview.column(col, width=100)
            while confNum < 2:
                conference = standings["conferences"][confNum]
                while divNum < 3:
                    division = conference["divisions"][divNum]
                    while teamNum < 5:
                        team = division["teams"][teamNum]
                        team_name = team["name"]
                        if confNum == 0:
                            team_conf = "West"
                        else:
                            team_conf = "East"
                        team_w = team["wins"]
                        team_l = team["losses"]
                        team_pct = team["win_pct"]
                        team_gb = team["games_behind"]["conference"]
                        team_ppg = team["points_for"]
                        team_papg = team["points_against"]
                        team_pd = team["point_diff"]        
                        treeview.heading("#0", text="Team")
                        treeview.heading("Conference", text="Confrence")
                        treeview.heading("Wins", text="Wins")
                        treeview.heading("Losses", text="Losses")
                        treeview.heading("Win Pct", text="Win Pct")
                        treeview.heading("GB", text="GB")
                        treeview.heading("PPG", text="PPG")
                        treeview.heading("PAPG", text="PAPG")
                        treeview.heading("PD", text="PD")
                        treeview.insert('',tk.END, text=team_name, values=(team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd))
                        teamNum += 1
                    divNum += 1
                    teamNum = 0
                confNum += 1
                divNum = 0
            treeview.pack()
            root.mainloop()
   
        def display_west_standings():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={key}"
            standings = requests.get(url).json()
            confNum = 0
            divNum = 0
            teamNum = 0
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('Western Conference Standings')
            def sort_treeview(treeview, col, descending):
                data = [(treeview.set(item, col), item) for item in treeview.get_children('')]
                data.sort(reverse=descending)
                for index, (val, item) in enumerate(data):
                    treeview.move(item, '', index)
                treeview.heading(col, command=lambda: sort_treeview(treeview, col, not descending))
            columns=("Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for col in columns:
                treeview.heading(col, text=col, command=lambda c=col: sort_treeview(treeview, c, False))
                treeview.column(col, width=100)
            while confNum < 1:
                conference = standings["conferences"][confNum]
                while divNum < 3:
                    division = conference["divisions"][divNum]
                    while teamNum < 5:
                        team = division["teams"][teamNum]
                        team_name = team["name"]
                        if confNum == 0:
                            team_conf = "West"
                        else:
                            team_conf = "East"
                        team_w = team["wins"]
                        team_l = team["losses"]
                        team_pct = team["win_pct"]
                        team_gb = team["games_behind"]["conference"]
                        team_ppg = team["points_for"]
                        team_papg = team["points_against"]
                        team_pd = team["point_diff"]        
                        treeview.heading("#0", text="Team")
                        treeview.heading("Conference", text="Confrence")
                        treeview.heading("Wins", text="Wins")
                        treeview.heading("Losses", text="Losses")
                        treeview.heading("Win Pct", text="Win Pct")
                        treeview.heading("GB", text="GB")
                        treeview.heading("PPG", text="PPG")
                        treeview.heading("PAPG", text="PAPG")
                        treeview.heading("PD", text="PD")
                        treeview.insert('',tk.END, text=team_name, values=(team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd))
                        teamNum += 1
                    divNum += 1
                    teamNum = 0
                confNum += 1
                divNum = 0
            treeview.pack()
            root.mainloop()
       
        def points_leaders():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/leaders.json?api_key={key}"
            stats = requests.get(url).json()
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('PPG Leaders')
            columns=("Name", "Pos", "Team", "PPG", "TS%")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for i in stats["categories"]:
                if i["name"] == "points" and i["type"] == "average":
                    leaders = i["ranks"]
                    for i in leaders:
                        rank = i["rank"]
                        name = i["player"]["full_name"]
                        pos = i["player"]["primary_position"]
                        team = i["teams"][0]["name"]
                        ppg = i["score"]
                        ts = i["total"]["true_shooting_pct"]
                        treeview.heading("#0", text="Rank")
                        treeview.heading("Name", text="Name")
                        treeview.heading("Pos", text="Pos")
                        treeview.heading("Team", text="Team")
                        treeview.heading("PPG", text="PPG")
                        treeview.heading("TS%", text="TS%")
                        treeview.insert('',tk.END, text=rank, values=(name, pos, team, ppg, ts))
            treeview.pack()
            root.mainloop()
        
        def assists_leaders():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/leaders.json?api_key={key}"
            stats = requests.get(url).json()
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('APG Leaders')
            columns=("Name", "Pos", "Team", "APG", "AST/TO")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for i in stats["categories"]:
                if i["name"] == "assists" and i["type"] == "average":
                    leaders = i["ranks"]
                    for i in leaders:
                        rank = i["rank"]
                        name = i["player"]["full_name"]
                        pos = i["player"]["primary_position"]
                        team = i["teams"][0]["name"]
                        apg = i["score"]
                        ast_to = i["total"]["assists_turnover_ratio"]
                        treeview.heading("#0", text="Rank")
                        treeview.heading("Name", text="Name")
                        treeview.heading("Pos", text="Pos")
                        treeview.heading("Team", text="Team")
                        treeview.heading("APG", text="APG")
                        treeview.heading("AST/TO", text="AST/TO")
                        treeview.insert('',tk.END, text=rank, values=(name, pos, team, apg, ast_to))
            treeview.pack()
            root.mainloop()
       
        def rebounds_leaders():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/leaders.json?api_key={key}"
            stats = requests.get(url).json()
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('RPG Leaders')
            columns=("Name", "Pos", "Team", "RPG", "ORPG")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for i in stats["categories"]:
                if i["name"] == "rebounds" and i["type"] == "average":
                    leaders = i["ranks"]
                    for i in leaders:
                        rank = i["rank"]
                        name = i["player"]["full_name"]
                        pos = i["player"]["primary_position"]
                        team = i["teams"][0]["name"]
                        rpg = i["score"]
                        orpg = i["average"]["off_rebounds"]
                        treeview.heading("#0", text="Rank")
                        treeview.heading("Name", text="Name")
                        treeview.heading("Pos", text="Pos")
                        treeview.heading("Team", text="Team")
                        treeview.heading("RPG", text="RPG")
                        treeview.heading("ORPG", text="ORPG")
                        treeview.insert('',tk.END, text=rank, values=(name, pos, team, rpg, orpg))
            treeview.pack()
            root.mainloop()
        
        def blocks_leaders():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/leaders.json?api_key={key}"
            stats = requests.get(url).json()
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('BPG Leaders')
            columns=("Name", "Pos", "Team", "BPG")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for i in stats["categories"]:
                if i["name"] == "blocks" and i["type"] == "average":
                    leaders = i["ranks"]
                    for i in leaders:
                        rank = i["rank"]
                        name = i["player"]["full_name"]
                        pos = i["player"]["primary_position"]
                        team = i["teams"][0]["name"]
                        bpg = i["score"]
                        treeview.heading("#0", text="Rank")
                        treeview.heading("Name", text="Name")
                        treeview.heading("Pos", text="Pos")
                        treeview.heading("Team", text="Team")
                        treeview.heading("BPG", text="BPG")
                        treeview.insert('',tk.END, text=rank, values=(name, pos, team, bpg))
            treeview.pack()
            root.mainloop()
       
        def steals_leaders():
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/leaders.json?api_key={key}"
            stats = requests.get(url).json()
            root = tk.Tk()
            root.geometry('1200x1200')
            root.title('SPL Leaders')
            columns=("Name", "Pos", "Team", "SPG")
            treeview = ttk.Treeview(root, height="500",columns=columns)
            for i in stats["categories"]:
             if i["name"] == "steals" and i["type"] == "average":
                leaders = i["ranks"]
                for i in leaders:
                    rank = i["rank"]
                    name = i["player"]["full_name"]
                    pos = i["player"]["primary_position"]
                    team = i["teams"][0]["name"]
                    spg = i["score"]
                    treeview.heading("#0", text="Rank")
                    treeview.heading("Name", text="Name")
                    treeview.heading("Pos", text="Pos")
                    treeview.heading("Team", text="Team")
                    treeview.heading("SPG", text="SPG")
                    treeview.insert('',tk.END, text=rank, values=(name, pos, team, spg))
            treeview.pack()
            root.mainloop()
        
        
        Nba_logo = Canvas(header_logo,height=200,width=400)
        Nba_logo.pack()
        path = f"/Users/ianhanauer/Desktop/College/Python151/Final-Project/Project/BackEnd/Nba_logo.png"
        image = Image.open(path)
        photo = ImageTk.PhotoImage(image)
        Nba_logo.create_image(200,100, image=photo)
        Nba_logo.image = photo
        
        
        
        Top_of_page = Label(header_text, text="Browse Today's NBA Matchups and Scores", justify='center')
        Top_of_page.pack(pady=20)
       
        todays_sched = Label(body_left, text= "Today's Schedule").pack()
        current_scedule_txt = Text(body_left, height=25, width=70)
        current_scedule_txt.pack()
        tmrw_sched_label = Label(body_right, text= "Tomorrow's Schedule").pack()
        tmrw_scedule_txt = Text(body_right, height=25,width=70)
        tmrw_scedule_txt.pack()
        
        get_scehudle = Button(bottom, font = 35, text = "Get Today's Scehudle", command= lambda:(current_scehudle(),upcoming_scehudle()), justify='center')
        get_scehudle.pack()
        
        close_window = Button(bottom, font = 35, text = "Close Window", command=window.destroy, justify='center')
        close_window.pack()
        
        window.configure(menu= menu)
        window.mainloop()
        
main1 = prototype()
main1.All()
