# %%
import random
import requests
import csv 
import json
import datetime
import tkinter as tk
from tkinter import * 
from tkinter import ttk
import time


class test1():
    def __init__(self) -> None:
        pass
    
    def All(self):
        window = Tk()
        window.geometry('900x900')
        window.title('Daily Nba Scoreboard') 
        game_select = StringVar()
        game_select.set("Select a Game")
        game_id = StringVar()
        game_id.set("")
        date_entry = StringVar()
        date_entry.get()    
        
        menu = Menu(window)
        Homepage_menu = Menu(menu, tearoff=True)
        Homepage_menu.add_command(label = "Homepage", activebackground='red', command = lambda: Homepage())
        Homepage_menu.add_command(label = "Quit", activebackground='red', command = lambda: exit())
        menu.add_cascade(label = 'Home', menu = Homepage_menu)

        Stats_menu= Menu(menu)
        Stats_menu.add_command(label = "League Stats", activebackground='red', command = lambda: Leuage_Stats_page())
        Stats_menu.add_command(label = "Confrence Stats 1 ", activebackground='red', command = lambda: Confrence_Stats_page_1())
        Stats_menu.add_command(label = "Confrence Stats 2 ", activebackground='red', command = lambda: Confrence_Stats_page_2())
        menu.add_cascade(label = 'Stats', menu= Stats_menu)
        
        Standings_menu= Menu(menu)
        Standings_menu.add_command(label = "League Standings", activebackground='red', command = lambda: Leuage_Standings_page())
        Standings_menu.add_command(label = "Confrence Standings 1", activebackground='red', command = lambda: Confrence_Standings_page_1())
        Standings_menu.add_command(label = "Confrence Standings 2 ", activebackground='red', command = lambda: Confrence_Standings_page_1())
        menu.add_cascade(label = 'Standings', menu= Standings_menu)

        Matchups_menu = Menu(menu)
        Matchups_menu.add_command(label ="Matchups", activebackground='red', command = lambda: Matchups_page())
        menu.add_cascade(label= "Matchups", menu=Matchups_menu)
        
        
        frame_1 = Frame(window)
        frame_1.grid(row=0, column=1)
        frame_2 = Frame(window)
        frame_2.grid(row=4, column=1)
        frame_3 = Frame(window)
        frame_3.grid(row=4,column=0)
        frame_4 = Frame(window)
        frame_4.grid(row=4,column=1, columnspan=2)
        frame_5 = Frame(window)
        frame_5.grid(row=10, column=1)
        
        def game_id():
            #date = datetime.date.today().strftime('%Y/%m/%d')
            date = '2024/04/07'
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB',
                        '5YA0Pzipp0awPWJzYaemW1g3dd0BQY3UoOdFXgL4',
                        'uG6ANcSN3T4idjLUKYbUt8vsoYn3LuE6gUQYeVO2']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/games/{date}/schedule.json?api_key={key}"
            headers = {"accept": "application/json"}
            reposnse = requests.get(url, headers=headers)
            game = reposnse.json()
            x = 0
            todays_game_dict = {}
            while IndexError is not True:
                try:
                    home_team = game['games'][x]['home']['name']
                    away_team = game['games'][x]['away']['name']
                    game_id = game['games'][x]['id']
                    home_team_alias = game['games'][x]['home']['alias']
                    away_team_alias = game['games'][x]['away']['alias']
                    todays_game_dict.update({f'{away_team} @ {home_team}':[game_id,away_team_alias, home_team_alias]})
                    x+=1     
                except:
                    break
            return todays_game_dict
        
        def scehudle():
            #date = datetime.date.today().strftime('%Y/%m/%d')
            date = '2024/04/07'
            api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB',
                        '5YA0Pzipp0awPWJzYaemW1g3dd0BQY3UoOdFXgL4',
                        'uG6ANcSN3T4idjLUKYbUt8vsoYn3LuE6gUQYeVO2']
            key = random.choice(api_list)
            url = f"https://api.sportradar.com/nba/trial/v8/en/games/{date}/schedule.json?api_key={key}"
            headers = {"accept": "application/json"}
            game = requests.get(url, headers=headers).json()
            x = 0
            todays_game_dict = {}
            Preview.delete("1.0", "end")
            while IndexError is not True:
                try:
                    home_team = game['games'][x]['home']['name']
                    away_team = game['games'][x]['away']['name']
                    time = game['games'][x]['scheduled']
                     #[
                    dt = datetime.datetime.strptime(time, '%Y-%m-%dT%H:%M:%SZ')
                    local_dt = dt.astimezone()
                    formatted_time = local_dt.strftime('%I:%M %p')
                    #] I got the syntax for how to change the times to how i want from Google search
                    Preview.insert(END, f'{away_team} @ {home_team} Scheduled for {formatted_time} Est\n')
                    Preview.insert(END,"----------------------------------------------------------------\n")
                    x+=1
                except:
                    break
              
        def exit():
            window.destroy()
        
        def destroy():
                frame_1.destroy()
                frame_2.destroy()
                frame_3.destroy()
                frame_4.destroy()
                frame_5.destroy() 
       
        def Homepage():
            destroy()
    
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            def scehudle():
                #date = datetime.date.today().strftime('%Y/%m/%d')
                date = '2024/04/07'
                api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                            'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                            'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                            'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                            'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB',
                            '5YA0Pzipp0awPWJzYaemW1g3dd0BQY3UoOdFXgL4',
                            'uG6ANcSN3T4idjLUKYbUt8vsoYn3LuE6gUQYeVO2']
                key = random.choice(api_list)
                url = f"https://api.sportradar.com/nba/trial/v8/en/games/{date}/schedule.json?api_key={key}"
                headers = {"accept": "application/json"}
                response = requests.get(url, headers=headers)
                game = response.json()
                x = 0
                todays_game_dict = {}
                Preview.delete("1.0", "end")
                while IndexError is not True:
                    try:
                        home_team = game['games'][x]['home']['name']
                        away_team = game['games'][x]['away']['name']
                        time = game['games'][x]['scheduled']
                        #[
                        dt = datetime.datetime.strptime(time, '%Y-%m-%dT%H:%M:%SZ')
                        local_dt = dt.astimezone()
                        formatted_time = local_dt.strftime('%I:%M %p')
                        #] I got the syntax for how to change the times to how i want from Google search
                        Preview.insert(END, f'{away_team} @ {home_team} Scheduled for {formatted_time} Est\n')
                        Preview.insert(END,"----------------------------------------------------------------\n")
                        x+=1
                    except:
                        break
            Top_of_page = Label(frame_1, text="Browse Todays Nba Matchups and Scores", justify='center')
            Top_of_page.pack(pady=20)
            Preview = Text(frame_2, height=16)
            Preview.pack()
            
            get_scehudle = Button(frame_5, font = 35, text = "Get Todays Scehudle", command=scehudle(), justify='center')
            get_scehudle.pack()
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
          
        def Matchups_page():
            destroy()

            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            #add NBA logo at the top of the page
            def Box_scores(game_id, option = None):
                id = game_id
                api_list = ['Tlzr3Og5bP7TcQkrqRHa12sZ5baCcFBJ7GdRZWEk',
                        'lVPf4Uz74v8Lb7FRmFdwYQgecskhHXS3aODzdHy1',
                        'cIm64jsILR6vy50AE2buetokdyXfAuH1aWQcdtGb',
                        'ut8MLfXDVZ1gB3BsiKAhl4nYFFj2nAkwaWGPEXrk',
                        'DGZWGVQNy29vEXDiVBRvg6klBgnu4DJ26fmFpcnB',
                        '5YA0Pzipp0awPWJzYaemW1g3dd0BQY3UoOdFXgL4',
                        'uG6ANcSN3T4idjLUKYbUt8vsoYn3LuE6gUQYeVO2']
                key = random.choice(api_list)
                Scoreboard.delete("1.0", "end")
                Scoreboard.insert(END, f"{option}\n")
                url = f"https://api.sportradar.com/nba/trial/v8/en/games/{id}/boxscore.json?api_key={key}"
                headers = {"accept": "application/json"}
                response = requests.get(url, headers=headers)
                game = response.json()
                clock = game['clock']
                quarter = game['quarter']
                away_team = game['away']['name']
                home_team = game['home']['name']
                away_score = game['away']['points']
                home_score = game['home']['points']
                away_timeouts_remaning = game['away']['remaining_timeouts']
                home_timeouts_remaning = game['home']['remaining_timeouts']
                score = (f'{away_team}: {away_score} Timeouts left: {away_timeouts_remaning} | {home_team}: {home_score} Timeouts left : {home_timeouts_remaning}')
                Scoreboard.insert(END,f"Time Remaining: {clock} | Quarter:{quarter}\n")
                Scoreboard.insert(END,f'{score}\n')
                
                
                
            matchups = game_id()
            def chose_game():
                option = game_select.get()
                value = matchups[option]
                game_id = value[0]
                Box_scores(game_id,option)
                print(game_id)
            
            
            Top_of_page = Label(frame_1, text="Browse Todays Nba Matchups and Scores", justify='center')
            Top_of_page.pack(pady=20)
            
            
            drop_label = Label(frame_3, text="Choose a Matchup").pack()
            dropdown = OptionMenu(frame_3, game_select, *matchups).pack()
            
            choose_button = Button(frame_3, text="Confirm Match Selection", command=chose_game)
            choose_button.pack(pady= 20)

            Scoreboard = Text(frame_2, height=16)
            Scoreboard.pack()

            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
            
        def Leuage_Stats_page():
            destroy()
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
                  
        def Confrence_Stats_page_1():
            destroy()
            
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack() 
            
        def Confrence_Stats_page_2():
            destroy()
            
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
        
        def Leuage_Standings_page():
            destroy()
            
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
            
        def Confrence_Standings_page_1():
            destroy()
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
            
        def Confrence_Standings_page_2():
            destroy()
            frame_1 = Frame(window)
            frame_1.grid(row=0, column=1)
            frame_2 = Frame(window)
            frame_2.grid(row=4, column=1)
            frame_3 = Frame(window)
            frame_3.grid(row=4,column=0)
            frame_4 = Frame(window)
            frame_4.grid(row=4,column=1, columnspan=2)
            frame_5 = Frame(window)
            frame_5.grid(row=10, column=1)
            
            close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
            close_window.pack()
              
            
        Top_of_page = Label(frame_1, text="Browse Todays Nba Matchups and Scores", justify='center')
        Top_of_page.pack(pady=20)
        Preview = Text(frame_2, height=16)
        Preview.pack()
        
        get_scehudle = Button(frame_5, font = 35, text = "Get Todays Scehudle", command=scehudle(), justify='center')
        get_scehudle.pack()
        
        close_window = Button(frame_5, font = 35, text = "Close Window", command=window.destroy, justify='center')
        close_window.pack()
        
        window.configure(menu= menu)
        window.mainloop()
        
main = test1()
main.All()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from tkinter import *
import tkMessageBox

def callback():
    if tkMessageBox.askokcancel("Quit", "Do you really wish to quit?"):
        root.destroy()

root = Tk()
root.protocol("WM_DELETE_WINDOW", callback)

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from tkinter import *
# ----> 2 import tkMessageBox
#       4 def callback():
#       5     if tkMessageBox.askokcancel("Quit", "Do you really wish to quit?"):
#
# ModuleNotFoundError: No module named 'tkMessageBox'
