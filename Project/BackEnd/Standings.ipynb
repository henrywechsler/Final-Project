# %%
import requests
import csv 
import json
import datetime
import pandas as pandasForSortingCSV
api_key = 'v4HTRgnYY94GBteg3f2py73d3wGVDgMD4sgLZtWP'

# %%
import tkinter as tk
from tkinter import ttk
from tkinter import filedialog
import csv
import matplotlib as mtb



def display_NBA_standings():
    url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={api_key}"
    csv_file = open("NBAStandings.csv", "w", newline = "", encoding = "utf-8")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Name", "Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD"])
    standings = requests.get(url).json()
    confNum = 0
    divNum = 0
    teamNum = 0
    while confNum < 2:
        conference = standings["conferences"][confNum]
        while divNum < 3:
            division = conference["divisions"][divNum]
            while teamNum < 5:
                team = division["teams"][teamNum]
                team_name = team["name"]
                if confNum == 0:
                    team_conf = "West"
                else:
                    team_conf = "East"
                team_w = team["wins"]
                team_l = team["losses"]
                team_pct = team["win_pct"]
                team_gb = team["games_behind"]["conference"]
                team_ppg = team["points_for"]
                team_papg = team["points_against"]
                team_pd = team["point_diff"]
                csv_writer.writerow([team_name, team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd])
                teamNum += 1
            divNum += 1
            teamNum = 0
        confNum += 1
        divNum = 0
    '''sheet = pandasForSortingCSV.read_csv("NBAStandings.csv")
    sheet.sort_values(["Win Pct"], ascending=[False],inplace=True)'''
    csv_file.close()
    csv_file1 = open("NBAStandings.csv", "r", newline = "", encoding = "utf-8")
    csv_file1. 

    return sheet
display_NBA_standings()

def trail():

    def display_csv_data():
        file = "NBAStandings.csv"
        try:
            with open(file, 'r', newline='') as file:
                csv_reader = csv.reader(file)
                header = next(csv_reader)  # Read the header row
                tree.delete(*tree.get_children())  # Clear the current data

                tree["columns"] = header
                for col in header:
                    tree.heading(col, text=col)
                    tree.column(col, width=100)

                for row in csv_reader:
                    tree.insert("", "end", values=row)

                status_label.config(text=f"CSV file loaded: {file}")

        except Exception as e:
            status_label.config(text=f"Error: {str(e)}")

    root = tk.Tk()
    root.title("CSV File Viewer")

    open_button = tk.Button(root, text="Open CSV File", command=display_csv_data)
    open_button.pack(padx=20, pady=10)

    tree = ttk.Treeview(root, show="headings")
    tree.pack(padx=20, pady=20, fill="both", expand=True)

    status_label = tk.Label(root, text="", padx=20, pady=10)
    status_label.pack()

    root.mainloop()
trail()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[5], line 46
#      44     csv_file.close()
#      45     return sheet
# ---> 46 display_NBA_standings()
#      48 def trail():
#      50     def display_csv_data():
#
# Cell In[5], line 42, in display_NBA_standings()
#      40     confNum += 1
#      41     divNum = 0
# ---> 42 sheet = pandasForSortingCSV.read_csv("NBAStandings.csv")
#      43 sheet.sort_values(["Win Pct"], ascending=[False],inplace=True)
#      44 csv_file.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
import requests
import tkinter as tk
from tkinter import ttk


def display_NBA_standings():
    api_key = 'v4HTRgnYY94GBteg3f2py73d3wGVDgMD4sgLZtWP'
    url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={api_key}"
    standings = requests.get(url).json()
    confNum = 0
    divNum = 0
    teamNum = 0
    while confNum < 2:
        root = tk.Tk()
        conference = standings["conferences"][confNum]
        while divNum < 3:
            division = conference["divisions"][divNum]
            while teamNum < 5:
                team = division["teams"][teamNum]
                team_name = team["name"]
                if confNum == 0:
                    team_conf = "West"
                else:
                    team_conf = "East"
                team_w = team["wins"]
                team_l = team["losses"]
                team_pct = team["win_pct"]
                team_gb = team["games_behind"]["conference"]
                team_ppg = team["points_for"]
                team_papg = team["points_against"]
                team_pd = team["point_diff"]
                
                treeview = ttk.Treeview(columns=("Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD"))
                treeview.heading("#0", text="Team")
                treeview.heading("Conference", text="Confrence")
                treeview.heading("Wins", text="Wins")
                treeview.heading("Losses", text="Losses")
                treeview.heading("Win Pct", text="Win Pct")
                treeview.heading("GB", text="GB")
                treeview.heading("PPG", text="PPG")
                treeview.heading("PAPG", text="PAPG")
                treeview.heading("PD", text="PD")
                treeview.insert("", tk.END, text=team_name, values=(team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd))
                teamNum += 1
            divNum += 1
            teamNum = 0
        confNum += 1
        divNum = 0
    

    treeview.pack()
    root.mainloop()
display_NBA_standings()

# %%
def display_east_standings():
    url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={api_key}"
    csv_file = open("EastStandings.csv", "w", newline = "", encoding = "utf-8")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Name", "Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD"])
    standings = requests.get(url).json()
    confNum = 1
    divNum = 0
    teamNum = 0
    while confNum < 2:
        conference = standings["conferences"][confNum]
        while divNum < 3:
            division = conference["divisions"][divNum]
            while teamNum < 5:
                team = division["teams"][teamNum]
                team_name = team["name"]
                team_conf = "East"
                team_w = team["wins"]
                team_l = team["losses"]
                team_pct = team["win_pct"]
                team_gb = team["games_behind"]["conference"]
                team_ppg = team["points_for"]
                team_papg = team["points_against"]
                team_pd = team["point_diff"]
                csv_writer.writerow([team_name, team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd])
                teamNum += 1
            divNum += 1
            teamNum = 0
        confNum += 1
        divNum = 0
    csv_file.close()
    sheet = pandasForSortingCSV.read_csv("EastStandings.csv")
    sheet.sort_values(["Win Pct"], ascending=[False],inplace=True)
    return sheet
display_east_standings()
# Out:
#          Name Conference  Wins  Losses  Win Pct    GB     PPG    PAPG     PD
# 5     Celtics       East    62      16    0.795   0.0  120.82  109.17  11.65
# 10      Bucks       East    47      31    0.603  15.0  119.74  116.83   2.91
# 0       Magic       East    46      32    0.590  16.0  110.60  108.26   2.35
# 6      Knicks       East    46      32    0.590  16.0  112.46  107.96   4.50
# 11  Cavaliers       East    46      33    0.582  16.5  112.49  110.13   2.37
# 12     Pacers       East    45      34    0.570  17.5  122.70  120.17   2.53
# 7       76ers       East    44      35    0.557  18.5  114.49  111.98   2.52
# 1        Heat       East    43      35    0.551  19.0  110.00  108.46   1.54
# 13      Bulls       East    37      41    0.474  25.0  111.72  113.39  -1.67
# 2       Hawks       East    36      42    0.462  26.0  118.68  120.31  -1.63
# 8        Nets       East    31      48    0.392  31.5  110.77  113.51  -2.73
# 9     Raptors       East    25      53    0.321  37.0  112.59  118.62  -6.02
# 3     Hornets       East    19      59    0.244  43.0  106.45  116.60 -10.15
# 4     Wizards       East    15      64    0.190  47.5  113.38  122.76  -9.38
# 14    Pistons       East    13      65    0.167  49.0  110.27  119.21  -8.94

# %%
def display_west_standings():
    url = f"https://api.sportradar.com/nba/trial/v8/en/seasons/2023/REG/standings.json?api_key={api_key}"
    csv_file = open("WestStandings.csv", "w", newline = "", encoding = "utf-8")
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Name", "Conference", "Wins", "Losses", "Win Pct", "GB", "PPG", "PAPG", "PD"])
    standings = requests.get(url).json()
    confNum = 0
    divNum = 0
    teamNum = 0
    while confNum < 1:
        conference = standings["conferences"][confNum]
        while divNum < 3:
            division = conference["divisions"][divNum]
            while teamNum < 5:
                team = division["teams"][teamNum]
                team_name = team["name"]
                team_conf = "West"
                team_w = team["wins"]
                team_l = team["losses"]
                team_pct = team["win_pct"]
                team_gb = team["games_behind"]["conference"]
                team_ppg = team["points_for"]
                team_papg = team["points_against"]
                team_pd = team["point_diff"]
                csv_writer.writerow([team_name, team_conf, team_w, team_l, team_pct, team_gb, team_ppg, team_papg, team_pd])
                teamNum += 1
            divNum += 1
            teamNum = 0
        confNum += 1
        divNum = 0
    csv_file.close()
    sheet = pandasForSortingCSV.read_csv("WestStandings.csv")
    sheet.sort_values(["Win Pct"], ascending=[False],inplace=True)
    return sheet
display_west_standings()
# Out:
#              Name Conference  Wins  Losses  Win Pct    GB     PPG    PAPG  \
# 5    Timberwolves       West    54      24    0.692   0.0  112.97  105.99
# 6         Nuggets       West    54      24    0.692   0.0  114.68  109.65
# 7         Thunder       West    53      25    0.679   1.0  119.85  113.49
# 10       Clippers       West    50      28    0.641   4.0  116.08  112.44
# 0       Mavericks       West    48      30    0.615   6.0  118.56  115.96
# 1        Pelicans       West    46      32    0.590   8.0  114.99  110.49
# 11           Suns       West    46      32    0.590   8.0  116.45  113.53
# 12          Kings       West    45      33    0.577   9.0  116.69  115.10
# 13         Lakers       West    45      34    0.570   9.5  117.87  117.32
# 14       Warriors       West    43      35    0.551  11.0  117.83  115.40
# 2         Rockets       West    38      40    0.487  16.0  114.15  113.35
# 8            Jazz       West    29      49    0.372  25.0  115.89  120.78
# 3       Grizzlies       West    27      51    0.346  27.0  105.91  112.69
# 9   Trail Blazers       West    21      57    0.269  33.0  106.94  115.58
# 4           Spurs       West    19      59    0.244  35.0  112.27  119.17
#
#       PD
# 5   6.99
# 6   5.03
# 7   6.36
# 10  3.64
# 0   2.60
# 1   4.50
# 11  2.92
# 12  1.59
# 13  0.56
# 14  2.44
# 2   0.81
# 8  -4.90
# 3  -6.78
# 9  -8.64
# 4  -6.90
